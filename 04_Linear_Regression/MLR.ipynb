# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("Advertising_Dataset.csv", sep=",")
data = {'TV':df['TV'].values,'Radio':df['Radio'].values,'Newspaper':df['Newspaper'].values}
df_oranlar = pd.DataFrame(data)
df_oranlar
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)
y_test
# Out:
# 126     6.6
# 104    20.7
# 99     17.2
# 92     19.4
# 111    21.8
# 167    17.2
# 116    12.2
# 96     16.7
# 52     22.6
# 69     22.3
# 164    11.9
# 124    19.7
# 182     8.7
# 154    20.6
# 125    10.6
# 196    14.0
# 194    17.3
# 177    16.7
# 163    18.0
# 31     11.9
# 11     17.4
# 73     11.0
# 15     22.4
# 41     17.1
# 97     20.5
# 128    24.7
# 133    19.6
# 82     11.3
# 139    20.7
# 123    15.2
# 83     13.6
# 65     11.3
# 151    11.6
# 162    19.9
# 170     8.4
# 77     14.2
# 32     13.2
# 173    16.7
# 174    16.5
# 85     20.2
# 168    17.1
# 112    17.1
# 171    17.5
# 181    17.2
# 7      13.2
# 46     10.6
# 75      8.7
# 28     18.9
# 29     10.5
# 195     7.6
# 40     16.6
# 153    16.0
# 115    12.6
# 64     16.0
# 59     18.4
# 1      10.4
# 192     5.9
# 136     9.5
# 152    16.6
# 161    13.3
# Name: Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# y = b0 + b1(x1)+ b2(x2)+b3(x3)+.......

# %%
print("Intercept:", mlr.intercept_)
# Out:
# Intercept: 4.334595861728431

# %%
print("Coefficents:", list(zip(x, mlr.coef_)))
# Out:
# Coefficents: [('TV', 0.053829108667250075), ('Radio', 0.11001224388558056), ('Newspaper', 0.006289950146130346)]

# %%
y_pred = mlr.predict(x_test)
print("prediction for test set: {}".format(y_pred))
# Out:
# prediction for test set: [ 9.35221067 20.96344625 16.48851064 20.10971005 21.67148354 16.16054424
#  13.5618056  15.39338129 20.81980757 21.00537077 12.29451311 20.70848608
#   8.17367308 16.82471534 10.48954832  9.99530649 16.34698901 14.5758119
#  17.23065133 12.56890735 18.55715915 12.12402775 20.43312609 17.78017811
#  16.73623408 21.60387629 20.13532087 10.82559967 19.12782848 14.84537816
#  13.13597397  9.07757918 12.07834143 16.62824427  8.41792841 14.0456697
#   9.92050209 14.26101605 16.76262961 17.17185467 18.88797595 15.50165469
#  15.78688377 16.86266686 13.03405813 10.47673934 10.6141644  20.85264977
#  10.1517568   6.88471443 17.88702583 18.16013938 12.55907083 16.28189561
#  18.98024679 11.33714913  5.91026916 10.06159509 17.62383031 13.19628335]

# %%
mlr_dff = pd.DataFrame({"Actual values": y_test, "Prediciton values":y_pred})
mlr_dff.head()
# Out:
#      Actual values  Prediciton values
# 126            6.6           9.352211
# 104           20.7          20.963446
# 99            17.2          16.488511
# 92            19.4          20.109710
# 111           21.8          21.671484

# %%
from sklearn import metrics 
meansqerr = metrics.mean_squared_error(y_test,y_pred)
print("R squared: {:.2f}".format(mlr.score(x,y)*100))
print("Mean Squared error:", meansqerr)
# Out:
# R squared: 90.11
# Mean Squared error: 2.6360765623280646
